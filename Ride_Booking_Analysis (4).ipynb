# %% [markdown]
# **Ride booking Dataset |Exploratory Data Analysis(EDA)**

# %% [markdown]
# Objective:
#
# To uncover meaningful patterns ,perform data cleaning and derive actionable insights of the provided dataset by performing Exploratory Data Analysis of the dataset.
#
# scope:
# Identify various trends
#
# Clean and preprocess raw data
#
# visualize and interperet key statistics of the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import pandas as pd
df=pd.read_csv('/content/Ride_booking.csv')

# %%
df.head()
# Out:
#          Date      Time    Booking ID   Booking Status   Customer ID  \
# 0  2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1  2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2  2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3  2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4  2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
#
#     Vehicle Type      Pickup Location      Drop Location  Avg VTAT  Avg CTAT  \
# 0          eBike          Palam Vihar            Jhilmil       NaN       NaN
# 1       Go Sedan        Shastri Nagar  Gurgaon Sector 56       4.9      14.0
# 2           Auto              Khandsa      Malviya Nagar      13.4      25.8
# 3  Premier Sedan  Central Secretariat           Inderlok      13.1      28.5
# 4           Bike     Ghitorni Village        Khan Market       5.3      19.6
#
#    ...  Reason for cancelling by Customer Cancelled Rides by Driver  \
# ...

# %%
df.shape
# Out:
# (150000, 21)

# %%
df
# Out:
#               Date      Time    Booking ID   Booking Status   Customer ID  \
# 0       2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...            ...       ...           ...              ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Booking ID', 'Booking Status', 'Customer ID',
#        'Vehicle Type', 'Pickup Location', 'Drop Location', 'Avg VTAT',
#        'Avg CTAT', 'Cancelled Rides by Customer',
#        'Reason for cancelling by Customer', 'Cancelled Rides by Driver',
#        'Driver Cancellation Reason', 'Incomplete Rides',
#        'Incomplete Rides Reason', 'Booking Value', 'Ride Distance',
#        'Driver Ratings', 'Customer Rating', 'Payment Method'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Date                               150000 non-null  object
#  1   Time                               150000 non-null  object
#  2   Booking ID                         150000 non-null  object
#  3   Booking Status                     150000 non-null  object
#  4   Customer ID                        150000 non-null  object
#  5   Vehicle Type                       150000 non-null  object
#  6   Pickup Location                    150000 non-null  object
#  7   Drop Location                      150000 non-null  object
#  8   Avg VTAT                           139500 non-null  float64
#  9   Avg CTAT                           102000 non-null  float64
#  10  Cancelled Rides by Customer        10500 non-null   float64
# ...

# %%
df.describe(include='all')
# Out:
#               Date      Time    Booking ID Booking Status   Customer ID  \
# count       150000    150000        150000         150000        150000
# unique         365     62910        148767              5        148788
# top     2024-11-16  17:44:57  "CNR6337479"      Completed  "CID6715450"
# freq           462        16             3          93000             3
# mean           NaN       NaN           NaN            NaN           NaN
# std            NaN       NaN           NaN            NaN           NaN
# min            NaN       NaN           NaN            NaN           NaN
# 25%            NaN       NaN           NaN            NaN           NaN
# 50%            NaN       NaN           NaN            NaN           NaN
# 75%            NaN       NaN           NaN            NaN           NaN
# max            NaN       NaN           NaN            NaN           NaN
#
#        Vehicle Type Pickup Location Drop Location       Avg VTAT  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                                      0
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                              10500
# Avg CTAT                              48000
# Cancelled Rides by Customer          139500
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver            123000
# Driver Cancellation Reason           123000
# Incomplete Rides                     141000
# Incomplete Rides Reason              141000
# Booking Value                         48000
# Ride Distance                         48000
# Driver Ratings                        57000
# Customer Rating                       57000
# Payment Method                        48000
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Date                                  0.0
# Time                                  0.0
# Booking ID                            0.0
# Booking Status                        0.0
# Customer ID                           0.0
# Vehicle Type                          0.0
# Pickup Location                       0.0
# Drop Location                         0.0
# Avg VTAT                              7.0
# Avg CTAT                             32.0
# Cancelled Rides by Customer          93.0
# Reason for cancelling by Customer    93.0
# Cancelled Rides by Driver            82.0
# Driver Cancellation Reason           82.0
# Incomplete Rides                     94.0
# Incomplete Rides Reason              94.0
# Booking Value                        32.0
# Ride Distance                        32.0
# Driver Ratings                       38.0
# Customer Rating                      38.0
# Payment Method                       32.0
# dtype: float64

# %%
# Verify remaining columns
print("Remaining columns:\n", df.columns)
# Out:
# Remaining columns:
#  Index(['Date', 'Time', 'Booking ID', 'Booking Status', 'Customer ID',
#        'Vehicle Type', 'Pickup Location', 'Drop Location', 'Avg VTAT',
#        'Avg CTAT', 'Cancelled Rides by Customer',
#        'Reason for cancelling by Customer', 'Cancelled Rides by Driver',
#        'Driver Cancellation Reason', 'Incomplete Rides',
#        'Incomplete Rides Reason', 'Booking Value', 'Ride Distance',
#        'Driver Ratings', 'Customer Rating', 'Payment Method'],
#       dtype='object')

# %%
# Fill numeric columns with MEAN
numeric_cols = ["Avg VTAT", "Avg CTAT", "Booking Value", "Ride Distance", "Driver Ratings", "Customer Rating"]
for col in numeric_cols:
 df[col].fillna(df[col].mean(), inplace=True)
# Out:
# /tmp/ipython-input-2876182335.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)

# %%
# Fill categorical columns with MODE
categorical_cols = ["Payment Method"]

for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-1571848941.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Date                                      0
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                                  0
# Avg CTAT                                  0
# Cancelled Rides by Customer          139500
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver            123000
# Driver Cancellation Reason           123000
# Incomplete Rides                     141000
# Incomplete Rides Reason              141000
# Booking Value                             0
# Ride Distance                             0
# Driver Ratings                            0
# Customer Rating                           0
# Payment Method                            0
# dtype: int64

# %% [markdown]
# finallly we have either dropped or filled the missing values

# %%
df.head()
# Out:
#          Date      Time    Booking ID   Booking Status   Customer ID  \
# 0  2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1  2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2  2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3  2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4  2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
#
#     Vehicle Type      Pickup Location      Drop Location   Avg VTAT  \
# 0          eBike          Palam Vihar            Jhilmil   8.456352
# 1       Go Sedan        Shastri Nagar  Gurgaon Sector 56   4.900000
# 2           Auto              Khandsa      Malviya Nagar  13.400000
# 3  Premier Sedan  Central Secretariat           Inderlok  13.100000
# 4           Bike     Ghitorni Village        Khan Market   5.300000
#
#     Avg CTAT  ...  Reason for cancelling by Customer  \
# 0  29.149636  ...                                NaN
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
#list of columns to drop
cols_to_drop = [
    "Cancelled Rides by Customer",
   "Driver Cancellation Reason",
    "Incomplete Rides",
    "Incomplete Rides Reason",
    "Cancelled Rides by Driver"]

df.drop(columns=cols_to_drop, inplace=True)

# %% [markdown]
# we have removed all the duplicate values

# %%
import numpy as np
# Fill categorical nulls with mode
categorical_cols = df.select_dtypes(include='object').columns
for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

# Fill numeric nulls with median
numeric_cols = df.select_dtypes(include=np.number).columns
for col in numeric_cols:
    df[col].fillna(df[col].median(), inplace=True)
# Out:
# /tmp/ipython-input-4167081536.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# /tmp/ipython-input-4167081536.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# Date                                 0
# Time                                 0
# Booking ID                           0
# Booking Status                       0
# Customer ID                          0
# Vehicle Type                         0
# Pickup Location                      0
# Drop Location                        0
# Avg VTAT                             0
# Avg CTAT                             0
# Cancelled Rides by Customer          0
# Reason for cancelling by Customer    0
# Cancelled Rides by Driver            0
# Driver Cancellation Reason           0
# Incomplete Rides                     0
# Incomplete Rides Reason              0
# Booking Value                        0
# Ride Distance                        0
# Driver Ratings                       0
# Customer Rating                      0
# Payment Method                       0
# dtype: int64

# %%
# Fill numeric columns with MEAN
numeric_cols = ["Avg VTAT", "Avg CTAT", "Booking Value", "Ride Distance", "Driver Ratings", "Customer Rating"]
for col in numeric_cols:
 df[col].fillna(df[col].mean(), inplace=True)
# Out:
# /tmp/ipython-input-2876182335.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)

# %%
# Fill categorical columns with MODE
categorical_cols = ["Payment Method"]

for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-1571848941.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(subset=['Booking Status', 'Customer ID', 'Vehicle Type', 'Pickup Location', 'Drop Location'], inplace=True)

# %%
# Analyze distribution of Booking Status
print("Distribution of Booking Status:")
display(df['Booking Status'].value_counts())
print("\n")

# Analyze distribution of Vehicle Type
print("Distribution of Vehicle Type:")
display(df['Vehicle Type'].value_counts())
print("\n")

# Analyze distribution of Payment Method
print("Distribution of Payment Method:")
display(df['Payment Method'].value_counts())
# Out:
# Distribution of Booking Status:
# Booking Status
# Completed                93000
# Cancelled by Driver      27000
# No Driver Found          10500
# Cancelled by Customer    10500
# Incomplete                9000
# Name: count, dtype: int64
# Distribution of Vehicle Type:
# Vehicle Type
# Auto             37419
# Go Mini          29806
# Go Sedan         27141
# Bike             22517
# Premier Sedan    18111
# eBike            10557
# Uber XL           4449
# Name: count, dtype: int64
# Distribution of Payment Method:
# Payment Method
# UPI            93909
# Cash           25367
# Uber Wallet    12276
# Credit Card    10209
# Debit Card      8239
# Name: count, dtype: int64

# %%
#Numerical columns
for col in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
plt.figure(figsize=(8,6))
numeric_df = df.select_dtypes(include=np.number)
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
payment_methods = df['Payment Method'].value_counts()

# %%
payment_methods
# Out:
# Payment Method
# UPI            93909
# Cash           25367
# Uber Wallet    12276
# Credit Card    10209
# Debit Card      8239
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=payment_methods.values, y=payment_methods.index, palette='viridis')
plt.title("Payment Methods")
plt.xlabel("Number of Bookings")
plt.ylabel(" Payment Method")
plt.show()
# Out:
# /tmp/ipython-input-4038028937.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=payment_methods.values, y=payment_methods.index, palette='viridis')

# %% [markdown]
# Booking Status: A large majority of bookings are completed, followed by cancellations by drivers, no driver found, cancellations by customers, and a small percentage of incomplete rides. This suggests that while the service is generally successful in completing rides, driver availability and cancellations are significant factors to consider.
#
# Vehicle Type: 'Auto' is the most frequently booked vehicle type, followed by 'Go Mini', 'Go Sedan', 'Bike', 'Premier Sedan', 'eBike', and 'Uber XL'. This indicates the popularity of different vehicle types and could inform decisions about fleet management and availability.
#
# Payment Method: UPI is the most popular payment method by a significant margin, followed by Cash, Uber Wallet, Credit Card, and Debit Card. This highlights the importance of UPI as a primary payment option and could influence strategies for promoting other payment methods.

# %% [markdown]
# **Most active booking hours**

# %% [markdown]
# This bar chart visualizes the number of bookings across different time zones of the day.

# %% [markdown]
# **Most Preferred Uber Vehicle Types**
#
#
# This bar chart shows the number of bookings for different Uber vehicle categories. Auto emerges as the most popular choice, followed by Go Mini and Go Sedan, indicating a strong preference for economical and compact transport options.

# %%
sns.countplot(x='Vehicle Type', data=df, order=df['Vehicle Type'].value_counts().index, palette='pastel')
plt.title("Most opted Uber Vechiles")
plt.ylabel("Number of Bookings")
plt.xlabel("Car Type")
plt.show()
# Out:
# /tmp/ipython-input-1408742902.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Vehicle Type', data=df, order=df['Vehicle Type'].value_counts().index, palette='pastel')

# %%
location_counts = df['Pickup Location'].value_counts()

# %%
top_10 = location_counts.head(5)
least_10 = location_counts.tail(5)
#location_counts
print("Top 10 location", top_10)
print("Top 10 location", least_10)
# Out:
# Top 10 location Pickup Location
# Khandsa            949
# Barakhamba Road    946
# Saket              931
# Badarpur           921
# Pragati Maidan     920
# Name: count, dtype: int64
# Top 10 location Pickup Location
# Mandi House         800
# Noida Sector 18     799
# Laxmi Nagar         797
# Ashok Vihar         796
# Ghitorni Village    790
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10.values, y=top_10.index, palette='viridis')
plt.title("Top 5 Most Picked Locations")
plt.xlabel("Number of Pickups")
plt.ylabel("Location")
plt.show()
# Out:
# /tmp/ipython-input-1600259829.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10.values, y=top_10.index, palette='viridis')

# %% [markdown]
# This chart highlights the five most frequently selected pickup locations by customers. Khandsa leads the list, followed closely by Barakhamba Road, Kanhaiya Nagar, Madipur, and Subhash Chowk.
#
# These locations likely represent key travel hubs or densely populated areas, indicating high demand zones. Such insights can help Uber optimize driver allocation and improve service efficiency in these regions.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=least_10.values, y=least_10.index, palette='viridis')
plt.title("Least 5 Most Picked Locations")
plt.xlabel("Number of Pickups")
plt.ylabel("Location")
plt.show()
# Out:
# /tmp/ipython-input-2056738890.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=least_10.values, y=least_10.index, palette='viridis')

# %% [markdown]
# This visualization shows the five pickup points with the lowest booking counts. Faridabad Sector 15, Arjangarh, Chirag Delhi, Old Gurgaon, and Vinobapuri appear to be the least preferred or least active locations for Uber bookings.
#
# These areas may represent regions with lower demand, less population density, or limited Uber availability. Recognizing such zones can guide strategic expansion, marketing efforts, or fleet redistribution

# %%
payment_methods = df['Payment Method'].value_counts()

# %%
payment_methods
# Out:
# Payment Method
# UPI            93909
# Cash           25367
# Uber Wallet    12276
# Credit Card    10209
# Debit Card      8239
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=payment_methods.values, y=payment_methods.index, palette='viridis')
plt.title("Payment Methods")
plt.xlabel("Number of Bookings")
plt.ylabel(" Payment Method")
plt.show()
# Out:
# /tmp/ipython-input-4038028937.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=payment_methods.values, y=payment_methods.index, palette='viridis')

# %% [markdown]
# The majority of users prefer UPI (Unified Payments Interface) for their Uber rides, making it the most popular payment method by a significant margin. Cash payments come next, indicating a continued reliance on traditional payment methods.
#
# Other modes like Uber Wallet, Credit Card, and Debit Card are used by fewer users, possibly due to digital wallet preferences or ease of UPI integration.
#
# This insight can help Uber focus on maintaining seamless UPI support while potentially incentivizing wallet and card usage to diversify transaction channels.

# %% [markdown]
# **Average Time Comparison: Driver Arrival vs Trip Duration**

# %%
avg_vtat = df['Avg VTAT'].mean()
avg_ctat = df['Avg CTAT'].mean()

print(f"Avg VTAT: {avg_vtat:.2f} minutes")
print(f"Avg CTAT: {avg_ctat:.2f} minutes")
# Out:
# Avg VTAT: 8.46 minutes
# Avg CTAT: 29.15 minutes

# %%
avg_df = pd.DataFrame({
    'Type': ['Driver to Pickup (VTAT)', 'Trip Duration (CTAT)'],
    'Avg Time (min)': [avg_vtat, avg_ctat]
})


# Plot
plt.figure(figsize=(6, 5))
sns.barplot(x='Type', y='Avg Time (min)', data=avg_df, palette='Blues')
plt.title("Average Time Comparison: VTAT vs CTAT")
plt.ylabel("Time (minutes)")
plt.xlabel("")
plt.xticks(rotation=10)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3381102040.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Type', y='Avg Time (min)', data=avg_df, palette='Blues')

# %% [markdown]
# This chart compares two key time metrics:
#
# VTAT (Vehicle to Arrival Time): The average time taken by the driver to reach the pickup location is approximately 8.46 minutes.
#
# CTAT (Customer Trip Arrival Time): The actual trip duration from pickup to drop-off is significantly higher, averaging around 29.15 minutes.
#
# The data clearly shows that while driver arrival is relatively quick, the majority of time is spent in the actual ride - an important insight for understanding operational efficiency and customer time investment.

# %% [markdown]
# **Cancellation by the customer**

# %%
cancellation_counts = df['Reason for cancelling by Customer'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(
    cancellation_counts,
    labels=cancellation_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    shadow=True
)


plt.title('Reason for cancelling by Customer - Pie Chart')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# Booking Status: The majority of bookings are completed, but a significant number are cancelled by either the driver or the customer, or result in no driver being found. This suggests areas for improvement in driver availability and potentially addressing reasons for cancellations.
#
# Vehicle Type: 'Auto' is the most popular vehicle type, followed by 'Go Mini' and 'Go Sedan'. This indicates a strong preference for economical and compact options among users.
#
# Payment Method: UPI is overwhelmingly the most preferred payment method, highlighting the importance of seamless digital payment options.
#
# Pickup Locations: You've identified the top and least popular pickup locations, which can be valuable for optimizing driver distribution and identifying areas for potential growth or targeted marketing.
#
# Average Time Comparison: The average trip duration (CTAT) is significantly longer than the average time it takes for a driver to reach the pickup location (VTAT). This is expected but emphasizes that the majority of the customer's time is spent in the ride itself.
#
# Customer Cancellations: The pie chart shows the distribution of reasons for customer cancellations. "Wrong Address" is the most frequent reason, which could indicate issues with location accuracy or user input during booking.
